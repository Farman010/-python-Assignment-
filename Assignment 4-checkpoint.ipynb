# %%
from matplotlib import pyplot as plt

import numpy as np

fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.axis('equal')

langs = ['Programming_Fundamentals', 'ICT', 'Islamic_Studies', 'Basic_Electronic','Calculus']
Students = [68,80,62,75,85]

ax.pie(Students, labels=langs, autopct='%1.2f%%')

plt.show()
